# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd
import numpy as np
# Out:
#    A variable  value
# 0  1        B      2
# 1  2        B      3
# 2  3        B      4
# 3  4        B      5
# B    2    3    4    5
# A
# 1  3.0  NaN  NaN  NaN
# 2  NaN  4.0  NaN  NaN
# 3  NaN  NaN  5.0  NaN
# 4  NaN  NaN  NaN  6.0

# %%
redding = pd.read_html("https://en.wikipedia.org/wiki/Redding,_California")

# %%
weather=redding[0]

# %%
display(weather)
# Out:
#                                   Redding, California  \
# 0                                                City
# 1   Top: Sundial Bridge at Turtle Bay; middle: Cas...
# 2                                            FlagSeal
# 3    Location of Redding in Shasta County, California
# 4   ReddingLocation in the United StatesReddingRed...
# 5   Coordinates: 40°35′11″N 122°23′30″W﻿ / ﻿40.586...
# 6                                             Country
# 7                                               State
# 8                                              County
# 9                                        Incorporated
# 10                                         Founded by
# 11                                         Government
# 12                                             • Type
# 13                                            • Mayor
# 14                                            Area[1]
# 15                                            • Total
# 16                                             • Land
# 17                                            • Water
# 18                                       Elevation[2]
# 19                                  Population (2020)
# 20                                            • Total
# 21                                             • Rank
# 22                                          • Density
# 23                                            Demonym
# 24                                          Time zone
# 25                                     • Summer (DST)
# 26                                          ZIP codes
# 27                                          Area code
# 28                                          FIPS code
# 29                                   GNIS feature IDs
# 30                                            Website
#
#                                 Redding, California.1
# 0                                                City
# 1   Top: Sundial Bridge at Turtle Bay; middle: Cas...
# 2                                            FlagSeal
# 3    Location of Redding in Shasta County, California
# 4   ReddingLocation in the United StatesReddingRed...
# 5   Coordinates: 40°35′11″N 122°23′30″W﻿ / ﻿40.586...
# 6                                       United States
# 7                                          California
# 8                                              Shasta
# 9                                     October 4, 1887
# 10                                 Pierson B. Reading
# 11                                         Government
# 12                                    Council-manager
# 13                                    Tenessa Audette
# 14                                            Area[1]
# 15                           61.17 sq mi (158.44 km2)
# 16                           59.65 sq mi (154.48 km2)
# 17                        1.53 sq mi (3.96 km2) 2.50%
# 18                                     564 ft (172 m)
# 19                                  Population (2020)
# 20                                              93611
# 21                                 83rd in California
# 22                              1,500/sq mi (590/km2)
# 23                                         Reddingite
# 24                                    UTC−08:00 (PST)
# 25                                    UTC−07:00 (PDT)
# 26                          96001–96003, 96049, 96099
# 27                                                530
# 28                                           06-59920
# 29                                    277582, 2411531
# 30                                   Official website
